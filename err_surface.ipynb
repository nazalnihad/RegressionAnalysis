# %% [markdown]
# <a href="https://colab.research.google.com/github/nazalnihad/RegressionAnalysis/blob/main/err_surface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/lin_vals.csv")

# %%
df
# Out:
#      x     z
# 0  -10 -38.5
# 1   -9 -32.5
# 2   -8 -28.5
# 3   -7 -24.5
# 4   -6 -21.5
# 5   -5 -17.5
# 6   -4 -12.5
# 7   -3 -11.5
# 8   -2  -6.5
# 9   -1   0.5
# 10   0   3.5
# 11   1   4.5
# 12   2   9.5
# 13   3  12.5
# 14   4  20.5
# 15   5  24.5
# 16   6  25.5
# 17   7  28.5
# 18   8  32.5
# 19   9  40.5
# 20  10  43.5

# %%
m = np.arange(-10, 10, 0.1)
c = np.arange(-10, 10, 0.1)

# %%
# mc_set = [(i,j) for i,j in zip(m,c)]

# %%
mc = []
for i in m:
    for j in c:
        mc.append((i, j))

# %%
len(mc)
# Out:
# 40000

# %%
X = df['x']
Y = df['z']

# %%
err = np.zeros(len(mc_set))

for index, (i, j) in enumerate(mc_set):
    pred_y = i * X + j
    error = np.sum(np.abs(Y - pred_y))
    err[index] = error

err = err.reshape(len(m), len(c))

M, C = np.meshgrid(m, c)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(M, C, err, cmap='viridis')

ax.set_xlabel('m')
ax.set_ylabel('c')
ax.set_zlabel('Error')
plt.title('Error Surface')
plt.show()
